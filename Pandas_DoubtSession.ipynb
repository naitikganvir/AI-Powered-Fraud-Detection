# %% [markdown]
# <a href="https://colab.research.google.com/github/naitikganvir/AI-Powered-Fraud-Detection/blob/main/Pandas_DoubtSession.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas

# %% [markdown]
# Its a library used to wrking the table/datasets form of dayta
# used for data manupulation and analaysis

# %% [markdown]
# **Pandas helps us to store the data**
# -clean data
# -look at data
# -Change data
# -**analysis data**
# -**Prepare for visualization and ML model**

# %%
#Series in pandas
#Series is like column
import pandas as pd
l = ["Apple", "Banana", "Mango"]
series = pd.Series(l) #It convert into column verticial
print(series)
# Out:
# 0     Apple
# 1    Banana
# 2     Mango
# dtype: object

# %%
print(series.index)
print(series.values)
# Out:
# RangeIndex(start=0, stop=3, step=1)
# ['Apple' 'Banana' 'Mango']

# %%
#Dataframe
#2d data, they are tables (with rows and columns)

# %%
d = {
    "Name" : ["Naitik", "Arman", "Jia"],
    "Roll" : [1, 2, 3],
     "Marks" : [90, 50, 60]
}
df=pd.DataFrame(d)
print(df)
# Out:
#      Name  Roll  Marks
# 0  Naitik     1     90
# 1   Arman     2     50
# 2     Jia     3     60

# %%
#How to access columns
print(df["Name"])
# Out:
# 0    Naitik
# 1     Arman
# 2       Jia
# Name: Name, dtype: object

# %%
print(df["Marks"])
print(df[ "Roll"])
# Out:
# 0    90
# 1    50
# 2    60
# Name: Marks, dtype: int64
# 0    1
# 1    2
# 2    3
# Name: Roll, dtype: int64

# %%
#How to access the rows
print(df.loc["0", "Marks"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3284546199.py in <cell line: 0>()
#       1 #How to access the rows
# ----> 2 print(df.loc["0", "Marks"])
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1181             key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1182             if self._is_scalar_access(key):
# -> 1183                 return self.obj._get_value(*key, takeable=self._takeable)
#    1184             return self._getitem_tuple(key)
#    1185         else:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _get_value(self, index, col, takeable)
#    4219             #  results if our categories are integers that dont match our codes
#    4220             # IntervalIndex: IntervalTree has no get_loc
# -> 4221             row = self.index.get_loc(index)
# ...

# %%
print(df.loc["1", "Name"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3096191928.py in <cell line: 0>()
# ----> 1 print(df.loc["1", "Name"])
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1181             key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1182             if self._is_scalar_access(key):
# -> 1183                 return self.obj._get_value(*key, takeable=self._takeable)
#    1184             return self._getitem_tuple(key)
#    1185         else:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _get_value(self, index, col, takeable)
#    4219             #  results if our categories are integers that dont match our codes
#    4220             # IntervalIndex: IntervalTree has no get_loc
# -> 4221             row = self.index.get_loc(index)
# ...

# %%
# upload the file on the folder option... Dataset load
df = pd.read_csv('/content/Flight_Booking.csv')

print(df)
# Out:
#         Unnamed: 0    airline   flight source_city departure_time stops  \
# 0                0   SpiceJet  SG-8709       Delhi        Evening  zero
# 1                1   SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2                2    AirAsia   I5-764       Delhi  Early_Morning  zero
# 3                3    Vistara   UK-995       Delhi        Morning  zero
# 4                4    Vistara   UK-963       Delhi        Morning  zero
# ...            ...        ...      ...         ...            ...   ...
# 116459      116459  Air_India   AI-640   Bangalore  Early_Morning   one
# 116460      116460    Vistara   UK-812   Bangalore        Morning   one
# 116461      116461    Vistara   UK-816   Bangalore        Morning   one
# 116462      116462    Vistara   UK-812   Bangalore        Morning   one
# 116463      116463    Vistara   UK-816     Bangalo            NaN   NaN
#
#          arrival_time destination_city    class  duration  days_left    price
# ...

# %%
#Analysing the Data

# %% [markdown]
# Analysing the data
#
# - head()
# -tail()
# -info()
# -describe()
# -shape()

# %%
print(df.head(7)) #first seven rows
# Out:
#    Unnamed: 0   airline   flight source_city departure_time stops  \
# 0           0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1           1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2           2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3           3   Vistara   UK-995       Delhi        Morning  zero
# 4           4   Vistara   UK-963       Delhi        Morning  zero
# 5           5   Vistara   UK-945       Delhi        Morning  zero
# 6           6   Vistara   UK-927       Delhi        Morning  zero
#
#     arrival_time destination_city    class  duration  days_left   price
# 0          Night           Mumbai  Economy      2.17        1.0  5953.0
# 1        Morning           Mumbai  Economy      2.33        1.0  5953.0
# 2  Early_Morning           Mumbai  Economy      2.17        1.0  5956.0
# 3      Afternoon           Mumbai  Economy      2.25        1.0  5955.0
# 4        Morning           Mumbai  Economy      2.33        1.0  5955.0
# ...

# %%
print(df.tail(8)) #Last ke 8 rows dega
# Out:
#         Unnamed: 0    airline  flight source_city departure_time stops  \
# 116456      116456  Air_India  AI-573   Bangalore      Afternoon   one
# 116457      116457  Air_India  AI-610   Bangalore        Evening   one
# 116458      116458  Air_India  AI-748   Bangalore     Late_Night   one
# 116459      116459  Air_India  AI-640   Bangalore  Early_Morning   one
# 116460      116460    Vistara  UK-812   Bangalore        Morning   one
# 116461      116461    Vistara  UK-816   Bangalore        Morning   one
# 116462      116462    Vistara  UK-812   Bangalore        Morning   one
# 116463      116463    Vistara  UK-816     Bangalo            NaN   NaN
#
#          arrival_time destination_city    class  duration  days_left    price
# 116456          Night          Chennai  Economy     10.33       13.0  10744.0
# 116457  Early_Morning          Chennai  Economy     12.17       13.0  10744.0
# 116458          Night          Chennai  Economy     20.50       13.0  10744.0
# ...

# %%
#basic information of the datasets

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116464 entries, 0 to 116463
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        116464 non-null  int64
#  1   airline           116464 non-null  object
#  2   flight            116464 non-null  object
#  3   source_city       116464 non-null  object
#  4   departure_time    116463 non-null  object
#  5   stops             116463 non-null  object
#  6   arrival_time      116463 non-null  object
#  7   destination_city  116463 non-null  object
#  8   class             116463 non-null  object
#  9   duration          116463 non-null  float64
#  10  days_left         116463 non-null  float64
#  11  price             116463 non-null  float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 10.7+ MB
# None

# %%
#Describe => Statistical informtionn about data

print(df.describe())
# Out:
#           Unnamed: 0       duration      days_left          price
# count  116464.000000  116463.000000  116463.000000  116463.000000
# mean    58231.500000      11.098171      25.849532    6418.189949
# std     33620.405213       7.136395      13.656466    3677.095454
# min         0.000000       0.830000       1.000000    1694.000000
# 25%     29115.750000       5.830000      14.000000    4029.000000
# 50%     58231.500000       9.750000      26.000000    5603.000000
# 75%     87347.250000      14.920000      38.000000    7490.000000
# max    116463.000000      41.830000      49.000000   40354.000000

# %%
#Shape() => No. of rows and columns

print(df.shape)
# Out:
# (116464, 12)

# %%
#Column => Names of all columns

print(df.columns)
# Out:
# Index(['Unnamed: 0', 'airline', 'flight', 'source_city', 'departure_time',
#        'stops', 'arrival_time', 'destination_city', 'class', 'duration',
#        'days_left', 'price'],
#       dtype='object')

# %%
#datatypes =  tell datatypes in each columns

print(df.dtypes)
# Out:
# Unnamed: 0            int64
# airline              object
# flight               object
# source_city          object
# departure_time       object
# stops                object
# arrival_time         object
# destination_city     object
# class                object
# duration            float64
# days_left           float64
# price               float64
# dtype: object

# %% [markdown]
# Statitcal Summary/analysis
# Columnwise analaysis
